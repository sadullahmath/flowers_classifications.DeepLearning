# %%
import os
import pandas as pd
import tensorflow as tf
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.image import imread

# %%
my_data= 'flower_photos'

# %%
os.listdir(my_data)
# Out:
# ['test', 'train']

# %%
train_path = my_data+'/train/'
test_path = my_data+'/test/'

# %%
os.listdir(train_path)
# Out:
# ['Daisy_train',
#  'Dandelion_train',
#  'Roses_train',
#  'sunflowers_train',
#  'tulips_train']

# %%
os.listdir(test_path)
# Out:
# ['Daisy_test',
#  'Dandelion_test',
#  'Roses_test',
#  'sunflowers_test',
#  'tulips_test']

# %%
os.listdir(train_path+'Daisy_train')[:10]
# Out:
# ['10140303196_b88d3d6cec.jpg',
#  '10172379554_b296050f82_n.jpg',
#  '10172567486_2748826a8b.jpg',
#  '10172636503_21bededa75_n.jpg',
#  '10391248763_1d16681106_n.jpg',
#  '10437754174_22ec990b77_m.jpg',
#  '10437770546_8bb6f7bdd3_m.jpg',
#  '10437929963_bc13eebe0c.jpg',
#  '10466290366_cc72e33532.jpg',
#  '10466558316_a7198b87e2.jpg']

# %%
os.listdir(train_path+'Daisy_train')[10]
# Out:
# '10555749515_13a12a026e.jpg'

# %%
daisy_train1=train_path+'Daisy_train'+'/10555749515_13a12a026e.jpg'

# %%
imread(daisy_train1)
# Out:
# array([[[ 83,  96,  76],
#         [ 83,  98,  75],
#         [ 84, 100,  73],
#         ...,
#         [ 50,  56,  56],
#         [ 49,  55,  55],
#         [ 49,  55,  55]],
#
#        [[ 79, 101,  78],
#         [ 81, 101,  76],
#         [ 82, 102,  74],
#         ...,
#         [ 51,  57,  57],
#         [ 50,  56,  56],
#         [ 50,  56,  56]],
#
#        [[ 82, 100,  76],
#         [ 83, 101,  75],
#         [ 83, 101,  75],
#         ...,
#         [ 50,  56,  56],
#         [ 50,  56,  56],
#         [ 51,  55,  54]],
#
#        ...,
#
#        [[ 82,  86,  72],
#         [ 78,  82,  68],
#         [ 77,  81,  67],
#         ...,
#         [ 46,  71,  42],
#         [ 45,  67,  44],
#         [ 49,  62,  45]],
#
#        [[ 81,  87,  73],
#         [ 79,  83,  69],
#         [ 78,  81,  70],
#         ...,
#         [ 47,  70,  44],
#         [ 46,  65,  45],
#         [ 49,  59,  48]],
#
#        [[ 85,  91,  77],
#         [ 83,  86,  75],
#         [ 82,  85,  74],
# ...

# %%
daisy_img= imread(daisy_train1)

# %%
plt.imshow(daisy_img);

# %%
daisy_img.shape
# Out:
# (331, 500, 3)

# %%
os.listdir(train_path+'Roses_train')[:10]
# Out:
# ['10090824183_d02c613f10_m.jpg',
#  '10503217854_e66a804309.jpg',
#  '10894627425_ec76bbc757_n.jpg',
#  '11102341464_508d558dfc_n.jpg',
#  '11233672494_d8bf0a3dbf_n.jpg',
#  '11694025703_9a906fedc1_n.jpg',
#  '11944957684_2cc806276e.jpg',
#  '12045735155_42547ce4e9_n.jpg',
#  '12165480946_c4a3fe182d_n.jpg',
#  '12202373204_34fb07205b.jpg']

# %%
os.listdir(train_path+'Roses_train')[10]
# Out:
# '12238827553_cf427bfd51_n.jpg'

# %%
roses_train1 = train_path+'Roses_train'+'/12238827553_cf427bfd51_n.jpg'

# %%
roses_img= imread(roses_train1)

# %%
plt.imshow(roses_img);

# %%
roses_img.shape
# Out:
# (254, 320, 3)

# %%
os.listdir(train_path+'Dandelion_train')[:10]
# Out:
# ['10043234166_e6dd915111_n.jpg',
#  '10200780773_c6051a7d71_n.jpg',
#  '10294487385_92a0676c7d_m.jpg',
#  '10437652486_aa86c14985.jpg',
#  '10477378514_9ffbcec4cf_m.jpg',
#  '10486992895_20b344ce2d_n.jpg',
#  '10617162044_8740d4dd9f_n.jpg',
#  '10617191174_9a01753241_n.jpg',
#  '1074999133_1e4a1e042e.jpg',
#  '10777398353_5a20bb218c.jpg']

# %%
os.listdir(train_path+'Dandelion_train')[10]
# Out:
# '10778387133_9141024b10.jpg'

# %%
dandelion_train1 = train_path+'Dandelion_train'+'/10778387133_9141024b10.jpg'

# %%
dandelion_img= imread(dandelion_train1)

# %%
plt.imshow(dandelion_img);

# %%
dandelion_img.shape
# Out:
# (281, 500, 3)

# %%
os.listdir(train_path+'sunflowers_train')[:10]
# Out:
# ['1022552036_67d33d5bd8_n.jpg',
#  '10386503264_e05387e1f7_m.jpg',
#  '10386522775_4f8c616999_m.jpg',
#  '10386525005_fd0b7d6c55_n.jpg',
#  '10386525695_2c38fea555_n.jpg',
#  '10386540106_1431e73086_m.jpg',
#  '10386540696_0a95ee53a8_n.jpg',
#  '10386702973_e74a34c806_n.jpg',
#  '10862313945_e8ed9202d9_m.jpg',
#  '11881770944_22b4f2f8f6_n.jpg']

# %%
os.listdir(train_path+'sunflowers_train')[10]
# Out:
# '12282924083_fb80aa17d4_n.jpg'

# %%
sunflowers_train1 = train_path+'sunflowers_train'+'/12282924083_fb80aa17d4_n.jpg'

# %%
sunflowers_img= imread(sunflowers_train1)

# %%
plt.imshow(sunflowers_img);

# %%
sunflowers_img.shape
# Out:
# (240, 320, 3)

# %%
os.listdir(train_path+'tulips_train')[:10]
# Out:
# ['10094729603_eeca3f2cb6.jpg',
#  '10094731133_94a942463c.jpg',
#  '10128546863_8de70c610d.jpg',
#  '10163955604_ae0b830975_n.jpg',
#  '10164073235_f29931d91e.jpg',
#  '10686568196_b1915544a8.jpg',
#  '10995953955_089572caf0.jpg',
#  '112428919_f0c5ad7d9d_n.jpg',
#  '11441893003_ab83672800.jpg',
#  '11614202956_1dcf1c96a1.jpg']

# %%
os.listdir(train_path+'tulips_train')[9]
# Out:
# '11614202956_1dcf1c96a1.jpg'

# %%
tulips_train1 = train_path+'tulips_train'+'/11614202956_1dcf1c96a1.jpg'

# %%
tulips_img= imread(tulips_train1)

# %%
plt.imshow(tulips_img);

# %%
tulips_img.shape
# Out:
# (313, 500, 3)

# %%
x = []
y = []
for image in os.listdir(test_path+'tulips_test'):
    
    img = imread(test_path+'tulips_test/'+image)
    d1,d2,_ = img.shape
    x.append(d1)
    y.append(d2)

# %%
x[:10]
# Out:
# [209, 231, 333, 375, 375, 239, 229, 180, 233, 220]

# %%
y[:10]
# Out:
# [320, 320, 500, 500, 500, 320, 320, 240, 320, 320]

# %%
sns.scatterplot(x,y);
# Out:
# C:\Users\joujo\anaconda3\anaconda\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
np.mean(x)
# Out:
# 269.65

# %%
np.mean(y)
# Out:
# 361.4222222222222

# %%
image_shape = (240,240,3)

# %% [markdown]
# ## Preparing the Data for the model

# %%
tulips_img.max()

# %%
tulips_img.min()
# Out:
# 0

# %% [markdown]
# ['Daisy_train',
#  'Dandelion_train',
#  'Roses_train',
#  'sunflowers_train',
#  'tulips_train']

# %%
#tulips_test = tulips_img.astype('float32')
#tulips_train = tulips_img.astype('float32')
#tulips_test /= 255
#tulips_train /= 255

# %%
#Daisy_test = daisy_img.astype('float32')
#Daisy_train = daisy_img.astype('float32')
#Daisy_test /= 255
#Daisy_train /= 255

# %%
#Dandelion_test = dandelion_img.astype('float32')
#Dandelion_train =dandelion_img.astype('float32')
#Dandelion_test /= 255
#Dandelion_train /= 255

# %%
#Roses_test = roses_img.astype('float32')
#Roses_train =roses_img.astype('float32')
#Roses_test /= 255
#Roses_train /= 255

# %%
#sunflowers_test = sunflowers_img.astype('float32')
#sunflowers_train =sunflowers_img.astype('float32')
#sunflowers_test /= 255
#sunflowers_train /= 255

# %%
#tulips_test[15]
# Out:
# array([[0.10588235, 0.15294118, 0.09803922],
#        [0.10980392, 0.15294118, 0.09803922],
#        [0.10588235, 0.14901961, 0.09411765],
#        ...,
#        [0.12941177, 0.25490198, 0.16078432],
#        [0.12941177, 0.25490198, 0.16470589],
#        [0.11372549, 0.23921569, 0.14901961]], dtype=float32)

# %% [markdown]
# ## Creating the Model

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Activation, Dropout, Flatten, Dense, Conv2D, MaxPooling2D

# %%
model = Sequential()

model.add(Conv2D(filters=128, kernel_size=(3,3),input_shape=image_shape, padding='same', activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=128, kernel_size=(3,3),input_shape=image_shape, padding='same', activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(filters=64, kernel_size=(3,3),input_shape=image_shape, padding='same', activation='relu',))
model.add(MaxPooling2D(pool_size=(2, 2)))


model.add(Flatten())


model.add(Dense(32))
model.add(Activation('relu'))


model.add(Dense(5))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy',
              optimizer="adam",
              metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  conv2d_24 (Conv2D)          (None, 240, 240, 128)     3584
#
#  max_pooling2d_24 (MaxPoolin  (None, 120, 120, 128)    0
#  g2D)
#
#  conv2d_25 (Conv2D)          (None, 120, 120, 128)     147584
#
#  max_pooling2d_25 (MaxPoolin  (None, 60, 60, 128)      0
#  g2D)
#
#  conv2d_26 (Conv2D)          (None, 60, 60, 64)        73792
#
#  max_pooling2d_26 (MaxPoolin  (None, 30, 30, 64)       0
#  g2D)
#
#  flatten_8 (Flatten)         (None, 57600)             0
#
#  dense_16 (Dense)            (None, 32)                1843232
#
#  activation_16 (Activation)  (None, 32)                0
#
#  dense_17 (Dense)            (None, 5)                 165
#
#  activation_17 (Activation)  (None, 5)                 0
#
# ...
# Total params: 2,068,357
# Trainable params: 2,068,357
# Non-trainable params: 0
# ...

# %% [markdown]
# ## EarlyStopping

# %%
from tensorflow.keras.callbacks import EarlyStopping

# %%
early_stop = EarlyStopping(monitor='val_loss',patience=5)

# %% [markdown]
# ## ImageDataGenerater

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# %%
image_gen = ImageDataGenerator(rotation_range=20, 
                               width_shift_range=0.2, 
                               height_shift_range=0.2, 
                               #rescale=1/255, 
                               shear_range=0.2, 
                               zoom_range=0.2, 
                               horizontal_flip=True, 
                               fill_mode='nearest')

# %% [markdown]
# ## Training Data

# %%
batch_size = 32
train_image_gen = image_gen.flow_from_directory(train_path,
                                               target_size=(240,240),
                                                color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical', shuffle=True, seed=42)




test_image_gen = image_gen.flow_from_directory(test_path,
                                               target_size=(240,240),
                                               color_mode='rgb',
                                               batch_size=batch_size,
                                               class_mode='categorical', shuffle=True, seed=42)
# Out:
# Found 2867 images belonging to 5 classes.
# Found 804 images belonging to 5 classes.

# %%
train_image_gen.class_indices
# Out:
# {'Daisy_train': 0,
#  'Dandelion_train': 1,
#  'Roses_train': 2,
#  'sunflowers_train': 3,
#  'tulips_train': 4}

# %%
test_image_gen.class_indices
# Out:
# {'Daisy_test': 0,
#  'Dandelion_test': 1,
#  'Roses_test': 2,
#  'sunflowers_test': 3,
#  'tulips_test': 4}

# %%
results = model.fit(train_image_gen,epochs=10,
                    validation_data=test_image_gen,
                    callbacks=[early_stop])
# Out:
# Epoch 1/10
# 90/90 [==============================] - 834s 9s/step - loss: 1.6066 - accuracy: 0.2435 - val_loss: 1.6050 - val_accuracy: 0.2488
# Epoch 2/10
# 72/90 [=======================>......] - ETA: 3:45 - loss: 2.0390 - accuracy: 0.2392
